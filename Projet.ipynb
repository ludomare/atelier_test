# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
extrait1=pd.read_excel('LFB Incident data Last 3 years.xlsx')
colnames1=pd.Series(extrait1.columns)
# Out:
# 0                             IncidentNumber
# 1                                 DateOfCall
# 2                                    CalYear
# 3                                 TimeOfCall
# 4                                 HourOfCall
# 5                              IncidentGroup
# 6                        StopCodeDescription
# 7                         SpecialServiceType
# 8                           PropertyCategory
# 9                               PropertyType
# 10                          AddressQualifier
# 11                             Postcode_full
# 12                         Postcode_district
# 13                                      UPRN
# 14                                      USRN
# 15                        IncGeo_BoroughCode
# 16                        IncGeo_BoroughName
# 17                                ProperCase
# 18                           IncGeo_WardCode
# 19                           IncGeo_WardName
# 20                        IncGeo_WardNameNew
# ...

# %%
data=pd.read_csv('LFB Incident data - Datastore - with notional cost and UPRN from January 2009.csv',names=colnames1)
# Out:
# C:\Users\ludo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#   IncidentNumber   DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 0      235138081  01 Jan 2009     2009   00:00:37           0
# 1           1091  01 Jan 2009     2009   00:00:46           0
# 2           2091  01 Jan 2009     2009   00:03:00           0
# 3           3091  01 Jan 2009     2009   00:04:27           0
# 4           5091  01 Jan 2009     2009   00:05:39           0
#
#      IncidentGroup StopCodeDescription     SpecialServiceType  \
# 0  Special Service     Special Service                    RTC
# 1  Special Service     Special Service  Assist other agencies
# 2             Fire      Secondary Fire                    NaN
# 3             Fire      Secondary Fire                    NaN
# 4             Fire      Secondary Fire                    NaN
#
#   PropertyCategory                                 PropertyType  \
# 0     Road Vehicle                                         Car
# 1          Outdoor                         Lake/pond/reservoir
# ...

# %%
data = data.infer_objects()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1388197 entries, 0 to 1388196
# Data columns (total 38 columns):
#  #   Column                                  Non-Null Count    Dtype
# ---  ------                                  --------------    -----
#  0   IncidentNumber                          1388197 non-null  object
#  1   DateOfCall                              1388197 non-null  object
#  2   CalYear                                 1388197 non-null  int64
#  3   TimeOfCall                              1388197 non-null  object
#  4   HourOfCall                              1388197 non-null  int64
#  5   IncidentGroup                           1388197 non-null  object
#  6   StopCodeDescription                     1388197 non-null  object
#  7   SpecialServiceType                      430734 non-null   object
#  8   PropertyCategory                        1388197 non-null  object
#  9   PropertyType                            1388197 non-null  object
# ...

# %%
extrait2=pd.read_excel('LFB Mobilisation data Last 3 years.xlsx',nrows=5)
colnames2=pd.Series(extrait2.columns)

# %%
data2=pd.read_csv('LFB Mobilisation data from January 2009.csv',names=colnames2)
# Out:
# C:\Users\ludo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data2 = data2.infer_objects()
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1916074 entries, 0 to 1916073
# Data columns (total 22 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   IncidentNumber            object
#  1   CalYear                   int64
#  2   HourOfCall                int64
#  3   ResourceMobilisationId    int64
#  4   Resource_Code             object
#  5   PerformanceReporting      object
#  6   DateAndTimeMobilised      object
#  7   DateAndTimeMobile         object
#  8   DateAndTimeArrived        object
#  9   TurnoutTimeSeconds        float64
#  10  TravelTimeSeconds         float64
#  11  AttendanceTimeSeconds     int64
#  12  DateAndTimeLeft           object
#  13  DateAndTimeReturned       object
#  14  DeployedFromStation_Code  object
#  15  DeployedFromStation_Name  object
#  16  DeployedFromLocation      object
#  17  PumpOrder                 int64
#  18  PlusCode_Code             object
#  19  PlusCode_Description      object
# ...

# %%
data.isna().sum()
# Out:
# IncidentNumber                                 0
# DateOfCall                                     0
# CalYear                                        0
# TimeOfCall                                     0
# HourOfCall                                     0
# IncidentGroup                                  0
# StopCodeDescription                            0
# SpecialServiceType                        957463
# PropertyCategory                               0
# PropertyType                                   0
# AddressQualifier                               0
# Postcode_full                             662926
# Postcode_district                              0
# UPRN                                      141333
# USRN                                      162871
# IncGeo_BoroughCode                             0
# IncGeo_BoroughName                             0
# ProperCase                                     0
# IncGeo_WardCode                                1
# ...

# %%
data.duplicated().value_counts()
# Out:
# False    1388197
# dtype: int64

# %%
data.DateOfCall=pd.to_datetime(data.DateOfCall)

# %%
data.DateOfCall
# Out:
#   IncidentNumber DateOfCall  CalYear TimeOfCall  HourOfCall    IncidentGroup  \
# 0      235138081 2009-01-01     2009   00:00:37           0  Special Service
# 1           1091 2009-01-01     2009   00:00:46           0  Special Service
# 2           2091 2009-01-01     2009   00:03:00           0             Fire
# 3           3091 2009-01-01     2009   00:04:27           0             Fire
# 4           5091 2009-01-01     2009   00:05:39           0             Fire
#
#   StopCodeDescription     SpecialServiceType PropertyCategory  \
# 0     Special Service                    RTC     Road Vehicle
# 1     Special Service  Assist other agencies          Outdoor
# 2      Secondary Fire                    NaN          Outdoor
# 3      Secondary Fire                    NaN          Outdoor
# 4      Secondary Fire                    NaN          Outdoor
#
#                                   PropertyType  \
# 0                                         Car
# ...
